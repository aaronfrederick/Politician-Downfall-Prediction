# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime
import time
import pickle

# %%
###  Standard Cleaning Procedure  ###
def standard_df(df):
    df = df.iloc[1:]
    df = df.drop([0,1,3,6],axis=1)
    df.columns = ['Name','Entered Office','Exited Office','President']
    df = df.dropna(axis=0,how='all')
    df = df.fillna(method='ffill')
    df.Name = [name if 'Acting' not in name else np.nan for name in df.Name]
    df = df.dropna(axis=0,how='any')
    return df

# %%
###  URLs, Roles of Articles with White House Staffer Lists  ###
urls = ['https://en.wikipedia.org/wiki/List_of_Presidents_of_the_United_States',
        'https://en.wikipedia.org/wiki/List_of_Vice_Presidents_of_the_United_States',
        'https://en.wikipedia.org/wiki/List_of_Secretaries_of_State_of_the_United_States',
        'https://en.wikipedia.org/wiki/United_States_Secretary_of_Defense#List_of_Secretaries_of_Defense',
        'https://en.wikipedia.org/wiki/United_States_Secretary_of_the_Treasury#List_of_Secretaries_of_the_Treasury',
        'https://en.wikipedia.org/wiki/United_States_Secretary_of_Health_and_Human_Services#List_of_Secretaries_of_Health_and_Human_Services',
        'https://en.wikipedia.org/wiki/United_States_Attorney_General#List_of_Attorneys_General',
        'https://en.wikipedia.org/wiki/United_States_Secretary_of_Commerce#List_of_Secretaries_of_Commerce',
        'https://simple.wikipedia.org/wiki/United_States_Secretary_of_Labor',
        'https://en.wikipedia.org/wiki/United_States_Secretary_of_Housing_and_Urban_Development#List_of_Secretaries_of_Housing_and_Urban_Development',
        'https://en.wikipedia.org/wiki/United_States_Secretary_of_Transportation#Living_former_Secretaries_of_Transportation',
        'https://en.wikipedia.org/wiki/Administrator_of_the_Environmental_Protection_Agency',
        'https://en.wikipedia.org/wiki/Director_of_the_Federal_Bureau_of_Investigation',
        'https://en.wikipedia.org/wiki/United_States_Secretary_of_Homeland_Security#List_of_Secretaries_of_Homeland_Security',
        'https://en.wikipedia.org/wiki/National_Security_Advisor_(United_States)#List_of_National_Security_Advisors',
        'https://en.wikipedia.org/wiki/List_of_White_House_Chiefs_of_Staff']

roles = ['President',
        'Vice President',
        'Secretary of State',
        'Secretary of Defense',
        'Secretary of the Treasury',
        'Secretary of HHS',
        'Attorney General',
        'Secretary of Commerce',
        'Secretary of Labor',
        'Secretary of HUD',
        'Secretary of Transportation',
        'Director of FBI',
        'Secretary of Homeland Security',
        'Secretary of Homeland Security',
        'Chief of Staff']

# %%
###  Read URLs and attempt standard cleaning  ###

politician_data = []
for i, url in enumerate(urls):
    time.sleep(1)
    df = pd.read_html(url)[1]
    try:
        df = standard_df(df)
        df['Role'] = roles[i]
        politician_data.append(df)
    except:
        print(url)
# Out:
# https://en.wikipedia.org/wiki/List_of_Presidents_of_the_United_States
# https://en.wikipedia.org/wiki/List_of_Vice_Presidents_of_the_United_States
# https://en.wikipedia.org/wiki/List_of_Secretaries_of_State_of_the_United_States
# https://en.wikipedia.org/wiki/United_States_Secretary_of_Defense#List_of_Secretaries_of_Defense
# https://en.wikipedia.org/wiki/Administrator_of_the_Environmental_Protection_Agency
# https://en.wikipedia.org/wiki/Director_of_the_Federal_Bureau_of_Investigation
# https://en.wikipedia.org/wiki/National_Security_Advisor_(United_States)#List_of_National_Security_Advisors
# https://en.wikipedia.org/wiki/List_of_White_House_Chiefs_of_Staff

# %%
###  Reading and Cleaning Dataframe for Chief of Staff  ###

df = pd.read_html('http://en.wikipedia.org/wiki/List_of_White_House_Chiefs_of_Staff')[0]
df = df.iloc[1:]
df = df.drop([0,1,2,5],axis=1)
df.columns = ['Name','Term','Party','President']
df = df[df.Name != 'Vacant']
df = df.fillna(method='ffill')
df['Role'] = 'Chief of Staff'
df.Name = df.Name.apply(lambda x :re.sub('[^a-zA-Z ]','',x))
df.President = df.President.apply(lambda x :re.sub('[^a-zA-Z ]','',x))
df['Entered Office'] = df['Term'].apply(lambda x: x.split('–')[0])
df['Exited Office'] = df['Term'].apply(lambda x: x.split('–')[1])
politician_data.append(df)
#df

# %%
###  Reading and Cleaning Dataframe for National Security Advisor  ###

df = pd.read_html('https://en.wikipedia.org/wiki/National_Security_Advisor_(United_States)#List_of_National_Security_Advisors')[1]
df = df.iloc[2:]
df = df.drop([0,1,5],axis=1)
df.columns = ['Name','Entered Office','Exited Office','President']
df = df.dropna(axis=0,how='all')
df = df.fillna(method='ffill')
df['Role'] = 'National Security Advisor'
df.Name = df.Name.apply(lambda x :re.sub('[^a-zA-Z ]','',x))
df['Exited Office'] = df['Exited Office'].apply(lambda x : x[:-3] if '[' in x else x)
df['Exited Office'] = df['Exited Office'].apply(lambda x : x[:-1] if '[' in x else x)
df['Entered Office'] = df['Entered Office'].apply(lambda x : x[:-3] if '[' in x else x)
df['Entered Office'] = df['Entered Office'].apply(lambda x : x[:-1] if '[' in x else x)
politician_data.append(df)
#df

# %%
###  Reading and Cleaning Dataframe for Head of FBI  ###

df = pd.read_html('https://en.wikipedia.org/wiki/Director_of_the_Federal_Bureau_of_Investigation')[2]
df = df.iloc[1:]
df = df.drop([0,1,4,5],axis=1)
df.columns = ['Name','Term','President']
df = df.fillna(method='ffill')
df.Name = [name if 'Acting' not in name else np.nan for name in df.Name]
df = df.dropna(axis=0,how='any')
df['Entered Office'] = df['Term'].apply(lambda x: x.split('–')[0])
df['Exited Office'] = df['Term'].apply(lambda x: x.split('–')[1])
df['Role'] = 'Head of FBI'
politician_data.append(df)
#df

# %%
###  Reading and Cleaning Dataframe for Head of EPA  ###

df = pd.read_html('https://en.wikipedia.org/wiki/Administrator_of_the_Environmental_Protection_Agency')[1]
df = df.iloc[1:]
df = df.drop([0],axis=1)
df.columns = ['Name','Term','President']
df = df.dropna(axis=0,how='all')
df = df.fillna(method='ffill')
df.Name = [name if 'Acting' not in name else np.nan for name in df.Name]
df = df.dropna(axis=0,how='any')
df['Entered Office'] = df['Term'].apply(lambda x: x.split('–')[0])
df['Exited Office'] = df['Term'].apply(lambda x: x.split('–')[1])
df['Role'] = 'Head of EPA'
politician_data.append(df)
#df

# %%
###  Reading and Cleaning Dataframe for Secretary of Defense  ###

df = pd.read_html('https://en.wikipedia.org/wiki/United_States_Secretary_of_Defense#List_of_Secretaries_of_Defense')[1]
df = df.iloc[1:]
df = df.drop([0,1,3,6,7],axis=1)
df.columns = ['Name','Entered Office','Exited Office','President']
df = df.dropna(axis=0,how='all')
df = df.fillna(method='ffill')
df.Name = [name if 'Acting' not in name else np.nan for name in df.Name]
df = df.dropna(axis=0,how='any')
df['Role'] = 'Secretary of Defense'
politician_data.append(df)
#df

# %%
###  Reading and Cleaning Dataframe for Secretary of State  ###

df = pd.read_html('https://en.wikipedia.org/wiki/List_of_Secretaries_of_State_of_the_United_States')[2]
df = df.iloc[1:]
df = df.drop([0,1,3,6],axis=1)
df.columns = ['Name','Entered Office','Exited Office','President']
df = df.dropna(axis=0,how='all')
df = df.fillna(method='ffill')
df.Name = [name if 'Acting' not in name else np.nan for name in df.Name]
df = df.dropna(axis=0,how='any')
df.Name = df.Name.apply(lambda x : x[:-3] if '[' in x else x)
df['Exited Office'] = df['Exited Office'].apply(lambda x : x[:-3] if '[' in x else x)
df.President = df.President.apply(lambda x : x[:-3] if '[' in x else x)
df['Exited Office'] = df['Exited Office'].apply(lambda x : x[:-1] if '[' in x else x)
df['Exited Office'] = df['Exited Office'].apply(lambda x : x[:-2] if '[' in x else x)
df['Role'] = 'Secretary of State'
politician_data.append(df)
#df

# %%
###  Reading and Cleaning Dataframe for Vice President  ###

df = pd.read_html('https://en.wikipedia.org/wiki/List_of_Vice_Presidents_of_the_United_States')[1]
df = df.iloc[2:]
df = df.drop([0,2,4,5,7],axis=1)
df.columns = ['Term','Name','Party','President']
df = df.dropna(axis=0,how='all')
df.President = df.President.fillna(method='ffill')
df = df.dropna(axis=0,how='any')
df.Name = df.Name.apply(lambda x: x[:20])
df.Name = df.Name.apply(lambda x :re.sub('[^a-zA-Z ]','',x))
df.Name = df.Name.apply(lambda x : x[:-5] if 'Born' in x else x)
df.Name = df.Name.apply(lambda x : x[:-3] if 'Bor' in x else x)
df.Name = df.Name.apply(lambda x : 'Al Gore' if 'Gore' in x else x)
df.President = df.President.apply(lambda x : x[:-3] if '[' in x else x)
df['Entered Office'] = df['Term'].apply(lambda x: x.split('–')[0])
df['Exited Office'] = df['Term'].apply(lambda x: x.split('–')[1])
df['Role'] = 'Vice President'
politician_data.append(df)
#df

# %%
###  Reading and Cleaning Dataframe for President  ###

df = pd.read_html('https://en.wikipedia.org/wiki/List_of_Presidents_of_the_United_States')[1]
df = df.iloc[2:]
df = df.drop([0,2,4,5,7,8],axis=1)
df.columns = ['Term','Name','Party']
df = df.dropna(axis=0,how='all')
df.Party = df.Party.fillna(method='ffill')
df = df.dropna(axis=0,how='any')
df.Name = df.Name.apply(lambda x: x[:20])
df.Name = df.Name.apply(lambda x :re.sub('[^a-zA-Z ]','',x))
df.Name = df.Name.apply(lambda x : x[:-5] if 'Born' in x else x)
df.Name = df.Name.apply(lambda x : x[:-3] if 'Bor' in x else x)
df['Entered Office'] = df['Term'].apply(lambda x: x.split('–')[0])
df['Exited Office'] = df['Term'].apply(lambda x: x.split('–')[1])
df['Role'] = 'President'
df['President'] = df.Name
politician_data.append(df)
#df

# %%
df = politician_data[0]
for app_df in politician_data[1:]:
    df = df.append(app_df, sort=True)

df = df.reset_index()
df = df.drop('index',axis=1)
df = df.drop('Term',axis=1)
df.Party = df.Party.fillna('Not Available')
df['Entered Office'] = df['Entered Office'].apply(lambda x : x[:-3] if '[' in x else x)
df['President'] = df['President'].apply(lambda x : x.split('(')[0])
df['Party'] = df['Party'].apply(lambda x : x.split('(')[0])
df['Party'] = df['Party'].apply(lambda x : x.split('[')[0])
df['Exited Office'] = df['Exited Office'].apply(lambda x : x.split('(')[0])
df['Exited Office'] = df['Exited Office'].apply(lambda x : x.split('[')[0])
df['Entered Office'] = df['Entered Office'].apply(lambda x : x.split('[')[0])
df = df.drop(index=[18,81,90], axis=0) #ambda x : x.split()[0])
df = df.reset_index()
df = df.drop('index',axis=1)
df
# Out:
#          Entered Office       Exited Office                   Name  \
# 0    September 11, 1789    January 31, 1795     Alexander Hamilton
# 1      February 3, 1795   December 31, 1800    Oliver Wolcott, Jr.
# 2       January 1, 1801        May 13, 1801          Samuel Dexter
# 3          May 14, 1801    February 8, 1814        Albert Gallatin
# 4      February 9, 1814     October 5, 1814     George W. Campbell
# 5       October 6, 1814    October 21, 1816    Alexander J. Dallas
# 6      October 22, 1816       March 6, 1825    William H. Crawford
# 7         March 7, 1825       March 5, 1829           Richard Rush
# 8         March 6, 1829       June 20, 1831       Samuel D. Ingham
# 9        August 8, 1831        May 28, 1833           Louis McLane
# 10         May 29, 1833  September 22, 1833       William J. Duane
# 11   September 23, 1833       June 25, 1834         Roger B. Taney
# 12         July 1, 1834       March 3, 1841          Levi Woodbury
# 13        March 4, 1841  September 11, 1841           Thomas Ewing
# 14   September 13, 1841       March 1, 1843         Walter Forward
# 15        March 8, 1843         May 2, 1844        John C. Spencer
# 16         July 4, 1844       March 7, 1845         George M. Bibb
# 17        March 8, 1845       March 5, 1849       Robert J. Walker
# 18        July 23, 1850       March 6, 1853          Thomas Corwin
# 19        March 7, 1853       March 6, 1857          James Guthrie
# 20        March 7, 1857    December 8, 1860            Howell Cobb
# 21    December 12, 1860    January 14, 1861       Philip F. Thomas
# 22     January 15, 1861       March 6, 1861            John A. Dix
# 23        March 7, 1861       June 30, 1864        Salmon P. Chase
# 24         July 5, 1864       March 3, 1865   William P. Fessenden
# 25        March 9, 1865       March 3, 1869         Hugh McCulloch
# 26       March 12, 1869      March 16, 1873     George S. Boutwell
# 27       March 17, 1873        June 3, 1874  William A. Richardson
# 28         June 4, 1874       June 20, 1876    Benjamin H. Bristow
# 29         July 7, 1876       March 9, 1877         Lot M. Morrill
# ..                  ...                 ...                    ...
# 544       March 4, 1861      April 15, 1865        Abraham Lincoln
# 545      April 15, 1865       March 4, 1869         Andrew Johnson
# 546       March 4, 1869       March 4, 1877        Ulysses S Grant
# 547       March 4, 1877       March 4, 1881     Rutherford B Hayes
# 548       March 4, 1881  September 19, 1881       James A Garfield
# 549  September 19, 1881       March 4, 1885       Chester A Arthur
# 550       March 4, 1885       March 4, 1889       Grover Cleveland
# 551       March 4, 1889       March 4, 1893      Benjamin Harrison
# 552       March 4, 1893       March 4, 1897       Grover Cleveland
# 553       March 4, 1897  September 14, 1901       William McKinley
# 554  September 14, 1901       March 4, 1909     Theodore Roosevelt
# 555       March 4, 1909       March 4, 1913    William Howard Taft
# 556       March 4, 1913       March 4, 1921         Woodrow Wilson
# 557       March 4, 1921      August 2, 1923       Warren G Harding
# 558      August 2, 1923       March 4, 1929        Calvin Coolidge
# 559       March 4, 1929       March 4, 1933         Herbert Hoover
# 560       March 4, 1933      April 12, 1945    Franklin D Roosevel
# 561      April 12, 1945    January 20, 1953         Harry S Truman
# 562    January 20, 1953    January 20, 1961    Dwight D Eisenhower
# 563    January 20, 1961   November 22, 1963         John F Kennedy
# 564   November 22, 1963    January 20, 1969       Lyndon B Johnson
# 565    January 20, 1969      August 9, 1974          Richard Nixon
# 566      August 9, 1974    January 20, 1977            Gerald Ford
# 567    January 20, 1977    January 20, 1981           Jimmy Carter
# 568    January 20, 1981    January 20, 1989          Ronald Reagan
# 569    January 20, 1989    January 20, 1993        George H W Bush
# 570    January 20, 1993    January 20, 2001           Bill Clinton
# 571    January 20, 2001    January 20, 2009          George W Bush
# 572    January 20, 2009    January 20, 2017           Barack Obama
# 573    January 20, 2017           Incumbent           Donald Trump
#
#                                       Party               President  \
# 0                             Not Available       George Washington
# 1                             Not Available       George Washington
# 2                             Not Available       George Washington
# 3                             Not Available       George Washington
# 4                             Not Available       George Washington
# 5                             Not Available       George Washington
# 6                             Not Available       George Washington
# 7                             Not Available       John Quincy Adams
# 8                             Not Available          Andrew Jackson
# 9                             Not Available          Andrew Jackson
# 10                            Not Available          Andrew Jackson
# 11                            Not Available          Andrew Jackson
# 12                            Not Available          Andrew Jackson
# 13                            Not Available  William Henry Harrison
# 14                            Not Available  William Henry Harrison
# 15                            Not Available  William Henry Harrison
# 16                            Not Available  William Henry Harrison
# 17                            Not Available           James K. Polk
# 18                            Not Available        Millard Fillmore
# 19                            Not Available         Franklin Pierce
# 20                            Not Available          James Buchanan
# 21                            Not Available          James Buchanan
# 22                            Not Available          James Buchanan
# 23                            Not Available         Abraham Lincoln
# 24                            Not Available         Abraham Lincoln
# 25                            Not Available         Abraham Lincoln
# 26                            Not Available        Ulysses S. Grant
# 27                            Not Available        Ulysses S. Grant
# 28                            Not Available        Ulysses S. Grant
# 29                            Not Available        Ulysses S. Grant
# ..                                      ...                     ...
# 544                              Republican         Abraham Lincoln
# 545  National UnionApril 15, 1865 – c. 1868          Andrew Johnson
# 546                              Republican         Ulysses S Grant
# 547                              Republican      Rutherford B Hayes
# 548                              Republican        James A Garfield
# 549                              Republican        Chester A Arthur
# 550                              Democratic        Grover Cleveland
# 551                              Republican       Benjamin Harrison
# 552                              Democratic        Grover Cleveland
# 553                              Republican        William McKinley
# 554                              Republican      Theodore Roosevelt
# 555                              Republican     William Howard Taft
# 556                              Democratic          Woodrow Wilson
# 557                              Republican        Warren G Harding
# 558                              Republican         Calvin Coolidge
# 559                              Republican          Herbert Hoover
# 560                              Democratic     Franklin D Roosevel
# 561                              Democratic          Harry S Truman
# 562                              Republican     Dwight D Eisenhower
# 563                              Democratic          John F Kennedy
# 564                              Democratic        Lyndon B Johnson
# 565                              Republican           Richard Nixon
# 566                              Republican             Gerald Ford
# 567                              Democratic            Jimmy Carter
# 568                              Republican           Ronald Reagan
# 569                              Republican         George H W Bush
# 570                              Democratic            Bill Clinton
# 571                              Republican           George W Bush
# 572                              Democratic            Barack Obama
# 573                              Republican            Donald Trump
#
#                           Role
# 0    Secretary of the Treasury
# 1    Secretary of the Treasury
# 2    Secretary of the Treasury
# 3    Secretary of the Treasury
# 4    Secretary of the Treasury
# 5    Secretary of the Treasury
# 6    Secretary of the Treasury
# 7    Secretary of the Treasury
# 8    Secretary of the Treasury
# 9    Secretary of the Treasury
# 10   Secretary of the Treasury
# 11   Secretary of the Treasury
# 12   Secretary of the Treasury
# 13   Secretary of the Treasury
# 14   Secretary of the Treasury
# 15   Secretary of the Treasury
# 16   Secretary of the Treasury
# 17   Secretary of the Treasury
# 18   Secretary of the Treasury
# 19   Secretary of the Treasury
# 20   Secretary of the Treasury
# 21   Secretary of the Treasury
# 22   Secretary of the Treasury
# 23   Secretary of the Treasury
# 24   Secretary of the Treasury
# 25   Secretary of the Treasury
# 26   Secretary of the Treasury
# 27   Secretary of the Treasury
# 28   Secretary of the Treasury
# 29   Secretary of the Treasury
# ..                         ...
# 544                  President
# 545                  President
# 546                  President
# 547                  President
# 548                  President
# 549                  President
# 550                  President
# 551                  President
# 552                  President
# 553                  President
# 554                  President
# 555                  President
# 556                  President
# 557                  President
# 558                  President
# 559                  President
# 560                  President
# 561                  President
# 562                  President
# 563                  President
# 564                  President
# 565                  President
# 566                  President
# 567                  President
# 568                  President
# 569                  President
# 570                  President
# 571                  President
# 572                  President
# 573                  President
#
# [574 rows x 6 columns]

# %%
ent_dates = []
for item in df['Entered Office']:
    try:
        ent_dates.append(datetime.strptime(item, '%B %d, %Y'))
    except:
        try:
            l = item.split()
            w = ' '.join(l)
            ent_dates.append(datetime.strptime(w, '%B %d, %Y'))
        except:
            try:
                ent_dates.append(datetime.strptime(item, '%d %B %Y'))
            except:
                ent_dates.append(item.lower())
df['Entered Office'] = ent_dates

ex_dates = []
for item in df['Exited Office']:
    try:
        ex_dates.append(datetime.strptime(item, '%B %d, %Y'))
    except:
        try:
            l = item.split()
            w = ' '.join(l)
            ex_dates.append(datetime.strptime(w, '%B %d, %Y'))
        except:
            try:
                ex_dates.append(datetime.strptime(item, '%d %B %Y'))
            except:
                ex_dates.append(item.lower().strip(' '))
df['Exited Office'] = ex_dates

# %%
df = df.sort_values('Entered Office')
df = df.reset_index()
df = df.drop('index',axis=1)
df = df.iloc[100:]
df = df.reset_index()
df = df.drop('index',axis=1)
df.Name = df.Name.apply(lambda x: x.lower())
df.Name = df.Name.apply(lambda x: re.sub('[^a-z ]', '', x))
df['collectionname'] = df.Name.apply(lambda x: re.sub('[ ]','',x))

# %%
df.head()
# Out:
#   Entered Office        Exited Office              Name          Party  \
# 0     1861-03-04  1865-04-15 00:00:00   abraham lincoln     Republican
# 1     1861-03-04  1865-03-04 00:00:00   hannibal hamlin     Republican
# 2     1861-03-05  1864-11-24 00:00:00      edward bates  Not Available
# 3     1861-03-05  1865-04-15 00:00:00  william h seward  Not Available
# 4     1861-03-07  1864-06-30 00:00:00    salmon p chase  Not Available
#
#             President                       Role  collectionname
# 0     Abraham Lincoln                  President  abrahamlincoln
# 1  Abraham Lincoln[k]             Vice President  hannibalhamlin
# 2     Abraham Lincoln           Attorney General     edwardbates
# 3     Abraham Lincoln         Secretary of State  williamhseward
# 4     Abraham Lincoln  Secretary of the Treasury    salmonpchase

# %%
df.to_pickle('pol_df.pkl')

# %%
df1 = pd.read_pickle('pol_df.pkl')
#df1

# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017)
politician_db = client['politician_db_test']

# %%
from nytimesarticle import articleAPI
api = articleAPI('55855057701943e2bebecb6f113bce71')
df1 = df1.iloc[0:1]
for politician in df1.Name:
    df_entry = df1[df1.Name == politician]
    search = api.search(q = politician,
                       begin_date=18610304,
                       end_date=18650415)
    politician_col = politician_db[df_entry['collectionname'][df_entry.index[0]]]
    print('success for ', politician)
    print(search['response']['docs'])
    politician_col.insert_many(search['response']['docs'])
# Out:
# success for  abraham lincoln
# [{'web_url': 'https://www.nytimes.com/1861/12/24/news/sons-oe-new-england-anniversary-dinner-astor-house-superb-civil-military.html', 'snippet': '', 'print_page': '8', 'blog': {}, 'source': 'The New York Times', 'multimedia': [], 'headline': {'main': 'THE SONS OE NEW-ENGLAND.; Anniversary Dinner at the Astor House. A Superb Civil and Military Entertainment.Addresses by Wm. M. Evarts, Esq., Rev. Drs.Adams and Storrs, Hon. Robt. J. Walker,Hon. Charles Anderson, Gov.Curtin, Hon. H. J. Raymond, and Others.Anthem by Wm. Ross Wallace, and a Poem by John G. Saxe.Letters from president Lincoln, Secretary Seward, Lord Lyons, Governors Morgan, Andrew, and Others. PILGRIM.', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'persons', 'value': 'SAXE, JOHN GODFREY', 'rank': 0, 'major': None}, {'name': 'organizations', 'value': 'NEW ENGLAND SOCIETY', 'rank': 0, 'major': None}, {'name': 'subject', 'value': 'POETRY AND POETS', 'rank': 0, 'major': None}], 'pub_date': '1861-12-24T00:03:58Z', 'document_type': 'article', 'type_of_material': 'Article', '_id': '4fbfe30345c1498b0d04e135', 'word_count': 4430, 'score': 0.0}, {'web_url': 'https://www.nytimes.com/1862/02/16/news/proceedings-of-the-legislature-senate-assembly.html', 'snippet': '', 'print_page': '5', 'blog': {}, 'source': 'The New York Times', 'multimedia': [], 'headline': {'main': 'PROCEEDINGS OF THE LEGISLATURE.; SENATE. ASSEMBLY.', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [], 'pub_date': '1862-02-16T00:03:58Z', 'document_type': 'article', 'type_of_material': 'Article', '_id': '4fbfda9245c1498b0d02b553', 'word_count': 722, 'score': 0.0}, {'web_url': 'https://www.nytimes.com/1862/04/11/news/important-washington-proclamation-president-recommending-day-thanksgiving.html', 'snippet': 'By the President of the United States of America. A PROCLAMATION.  It has pleased Almighty God to vouchsafe signal victories to the land and naval forces engaged in suppressing an internal rebellion, and at the same time to avert from our country ...', 'print_page': '8', 'blog': {}, 'source': 'The New York Times', 'multimedia': [], 'headline': {'main': 'IMPORTANT FROM WASHINGTON.; Proclamation by the President Recommending a Day of Thanksgiving and Prayer.OPERATIONS OF THE PRESS CENSORSHIP Telegraphic Dispatches Cut Off from thePhiladelphia Inquirer.The Stevens Battery Appropriation Through the House.A New Treaty with England Regarding the Slave-trade. Proposed Modification of the Fugitive Slave Law.', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'persons', 'value': 'LINCOLN, ABRAHAM', 'rank': 0, 'major': None}, {'name': 'subject', 'value': 'CIVIL WAR (THE WAR BETWEEN THE STATES)', 'rank': 0, 'major': None}], 'pub_date': '1862-04-11T00:03:58Z', 'document_type': 'article', 'type_of_material': 'Article', '_id': '4fbfda7f45c1498b0d02ae51', 'word_count': 241, 'score': 0.0}, {'web_url': 'https://www.nytimes.com/1862/08/07/news/washington-great-war-meeting-held-capitol-important-speech-president-lincolnhis-78990186.html', 'snippet': 'An immense meeting was held at the east front of the Capitol this afternoon. It was preceded by the ringing of bells, the firing of cannon, and music from the Marine Band. The portico and platform were occupied by many ladies, military, civil and ...', 'abstract': 'McClellan army resumes offensive; Great war meeting held, Capitol Building, Washington; Lincoln and others speak; he backs McClellan and Stanton actions; resolutions', 'print_page': '1', 'blog': {}, 'source': 'The New York Times', 'multimedia': [], 'headline': {'main': "NEWS FROM WASHINGTON.; A Great War Meeting Held at the Capitol. Important Speech of President Lincoln.His Declarations in Regard to Gen. McClellan and the Secretary of War. POINTED RESOULTIONS ADOPTED.The Government Urged to Pro ...

# %%
len(search['response']['docs'])
# Out:
# 10

# %%
politician_col.find_one()
# Out:
# {'_id': '5bf244a33a125f5075bfaf31',
#  'web_url': 'https://www.nytimes.com/aponline/2018/11/19/us/ap-history.html',
#  'snippet': 'Today in History',
#  'blog': {},
#  'source': 'AP',
#  'multimedia': [],
#  'headline': {'main': 'Today in History',
#   'kicker': None,
#   'content_kicker': None,
#   'print_headline': 'Today in History',
#   'name': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [],
#  'pub_date': '2018-11-19T05:05:36+0000',
#  'document_type': 'article',
#  'news_desk': 'None',
#  'byline': {'original': 'By THE ASSOCIATED PRESS',
#   'person': [],
#   'organization': 'THE ASSOCIATED PRESS'},
#  'type_of_material': 'News',
#  'word_count': 842,
#  'score': 64.04402,
#  'uri': 'nyt://article/6a8ec232-1d07-53f0-a0ed-7f7be06a9bd1'}
